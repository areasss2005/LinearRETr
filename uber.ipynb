# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Uber.csv')
df.head(8) # reads the first 8 rows of the dataset 
df.tail(5) # gives us the last 5 rows of te dataset
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
# understand the shape and size of the given dataframe 
print(df.shape)
print(df.size)
# 1156 rows of data and 7 cololumns of data
# Out:
# (1156, 7)
# 8092

# %%
# provides a concise summary of the dataframe , it displays the information about the dataframe
# such as the number of columns and rows and the data types stores in the dataframe
#  tells us how many non-null charaters are present in the dataset 
# NON-NULL:
#--> meaning the dataframe in those columns do not take any null values
# also gives us the memoryy usage of tthe dataframe 
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
# gives us the count of all the non_null number of records 
df.count()
# Out:
# START_DATE*    1156
# END_DATE*      1155
# CATEGORY*      1155
# START*         1155
# STOP*          1155
# MILES*         1156
# PURPOSE*        653
# dtype: int64

# %%
# returns the amount oof values that are missing in the dataframe 
df.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
# works for any objects that are present in the dataframe 
df.isnull().any().any()
# Out:
# True

# %%
df.isnull().any() 
#checks wether any of the columns in the given data set is null and if is null then returns true
# Out:
# START_DATE*    False
# END_DATE*       True
# CATEGORY*       True
# START*          True
# STOP*           True
# MILES*         False
# PURPOSE*        True
# dtype: bool

# %%
null_cols = df.columns[df.isnull().any()]
null_cols = list(null_cols)
# get all the columns into a list so that we can perform any operation on them as a whole

# %%
# show all the records in the column purpose where there is data missing 
df[df['PURPOSE*'].isnull()]
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 32      1/19/2016 9:09    1/19/2016 9:23  Business       Whitebridge
# 85      2/9/2016 10:54    2/9/2016 11:07  Personal       Whitebridge
# 86      2/9/2016 11:43    2/9/2016 11:50  Personal        Northwoods
# 87      2/9/2016 13:36    2/9/2016 13:52  Personal        Tanglewood
# ...                ...               ...       ...               ...
# 1066  12/19/2016 14:37  12/19/2016 14:50  Business  Unknown Location
# 1069  12/19/2016 19:05  12/19/2016 19:17  Business         Islamabad
# 1071   12/20/2016 8:49   12/20/2016 9:24  Business  Unknown Location
# 1143  12/29/2016 20:53  12/29/2016 21:42  Business           Kar?chi
# 1155            Totals               NaN       NaN               NaN
#
#                     STOP*   MILES* PURPOSE*
# 1             Fort Pierce      5.0      NaN
# 32    Lake Wellingborough      7.2      NaN
# ...

# %%
df['PURPOSE*'].count()
# gives us the specific count of the given data that is present in the column PURPOSE
# Out:
# 653

# %%
col_names1 = df.columns
print(col_names1)
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')

# %%
col_names =['START_DATE', 'END_DATE', 'CATEGORY', 'START', 'STOP', 'MILES',
       'PURPOSE']
df.columns = col_names
print(col_names)
# Out:
# ['START_DATE', 'END_DATE', 'CATEGORY', 'START', 'STOP', 'MILES', 'PURPOSE']

# %%
# if there are many columns and we cannot manually change the column names we use the below 
df.columns = df.columns.str.replace("*","")

# %%
# we can also use the rename functions in pandas to rename all the given caolumns names
df.rename(columns={'CAT':'CATEGORY'})
df.head()
# Out:
#        START_DATE        END_DATE  CATEGORY        START             STOP  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
df.head()
# Out:
#        START_DATE        END_DATE  CATEGORY        START             STOP  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %% [markdown]
# Filtering the dataframes - 1

# %%
df[df.PURPOSE.isnull()]
# shows the entries where the Column with Purpose has any null elements in them
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 32      1/19/2016 9:09    1/19/2016 9:23  Business       Whitebridge
# 85      2/9/2016 10:54    2/9/2016 11:07  Personal       Whitebridge
# 86      2/9/2016 11:43    2/9/2016 11:50  Personal        Northwoods
# 87      2/9/2016 13:36    2/9/2016 13:52  Personal        Tanglewood
# ...                ...               ...       ...               ...
# 1066  12/19/2016 14:37  12/19/2016 14:50  Business  Unknown Location
# 1069  12/19/2016 19:05  12/19/2016 19:17  Business         Islamabad
# 1071   12/20/2016 8:49   12/20/2016 9:24  Business  Unknown Location
# 1143  12/29/2016 20:53  12/29/2016 21:42  Business           Kar?chi
# 1155            Totals               NaN       NaN               NaN
#
#                      STOP    MILES PURPOSE
# 1             Fort Pierce      5.0     NaN
# 32    Lake Wellingborough      7.2     NaN
# ...

# %%
# when we want the non-null elements in the dataframe of a specific column we use the 
df[~df.PURPOSE.isnull()]
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %% [markdown]
# FILTERING DATAFRAME - 2 : CONDITIONS WITHIN THE DATAFRAME

# %%
df[df['MILES']>30]
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 36     1/20/2016 13:25   1/20/2016 14:19  Business           Raleigh
# 108     2/16/2016 3:21    2/16/2016 4:13  Business        Katunayaka
# 232    3/17/2016 12:52   3/17/2016 15:11  Business            Austin
# 233    3/17/2016 15:16   3/17/2016 15:58  Business              Katy
# 245    3/19/2016 14:01   3/19/2016 14:57  Business        Sugar Land
# 246    3/19/2016 15:34   3/19/2016 16:38  Business           Houston
# 251    3/19/2016 19:33   3/19/2016 20:39  Business         Galveston
# 268    3/25/2016 13:24   3/25/2016 16:22  Business              Cary
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 295     4/2/2016 12:21    4/2/2016 14:47  Business         Kissimmee
# 296     4/2/2016 16:57    4/2/2016 18:09  Business     Daytona Beach
# ...

# %%
df.query('MILES>30')
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 36     1/20/2016 13:25   1/20/2016 14:19  Business           Raleigh
# 108     2/16/2016 3:21    2/16/2016 4:13  Business        Katunayaka
# 232    3/17/2016 12:52   3/17/2016 15:11  Business            Austin
# 233    3/17/2016 15:16   3/17/2016 15:58  Business              Katy
# 245    3/19/2016 14:01   3/19/2016 14:57  Business        Sugar Land
# 246    3/19/2016 15:34   3/19/2016 16:38  Business           Houston
# 251    3/19/2016 19:33   3/19/2016 20:39  Business         Galveston
# 268    3/25/2016 13:24   3/25/2016 16:22  Business              Cary
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 295     4/2/2016 12:21    4/2/2016 14:47  Business         Kissimmee
# 296     4/2/2016 16:57    4/2/2016 18:09  Business     Daytona Beach
# ...

# %%
df[df.MILES == 30]
# Out:
#           START_DATE         END_DATE  CATEGORY       START      STOP  MILES  \
# 486  6/27/2016 12:22  6/27/2016 13:02  Business  Mandeville  Metairie   30.0
#
#     PURPOSE
# 486     NaN

# %%
df[df.MILES != 30]
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
df.MILES.max() # gives us the maximum miles that uber ride was 
df.MILES.sort_values(ascending=False).head(5)
# as we say the ascending values , they are from small to large hence when we set to false 
# they give us the biggger values and when set to true gives us the lower values in the dataframe 
df[df.MILES == df.MILES.max()]
# shows the row that has the max miles
df.sort_values(by = 'MILES' , ascending=False).head(10)
# gives us the largest miles from the dataset and displayes the larghest 10 amongst them
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 1155            Totals               NaN       NaN               NaN
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 881   10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 776    9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
# 546    7/14/2016 16:39   7/14/2016 20:05  Business       Morrisville
# 559    7/17/2016 12:20   7/17/2016 15:25  Personal             Boone
# 297     4/2/2016 19:38    4/2/2016 22:36  Business      Jacksonville
# 299      4/3/2016 2:00     4/3/2016 4:16  Business          Florence
# 727    8/27/2016 16:15   8/27/2016 19:13  Business  Unknown Location
#
#                   STOP    MILES         PURPOSE
# 1155               NaN  12204.7             NaN
# 269       Jacksonville    310.3  Customer Visit
# 270          Kissimmee    201.0         Meeting
# ...

# %% [markdown]
# Remove the last row in miles

# %%
len(df)
df = df[df.MILES<1000]

# %%
len(df)
# Out:
# 1155

# %%
df = df[df.MILES<1000]

# %%
# get the summery of the numerical columns in the data 
df.describe()
# Out:
#              MILES
# count  1155.000000
# mean     10.566840
# std      21.579106
# min       0.500000
# 25%       2.900000
# 50%       6.000000
# 75%      10.400000
# max     310.300000

# %%
#droppping the rows which have null columns 
df_dropped = df.dropna()
#never use this on the orginal dataframe always use it on a copy 
df_dropped.shape
# Out:
# (653, 7)

# %% [markdown]
# PANDAS PROFILING
#
# using certain packages that will auto profile your data (then writing commandds )

# %%
pip install ydata_profiling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pydantic import BaseModel

class MyData(BaseModel):
    column1: int
    column2: str
    column3: float

# %%
import ydata_profiling as ydp

# Assuming your DataFrame is loaded as 'df'
profile = ydp.ProfileReport(df)
profile.to_file('output.html')  # Save report as HTML
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# c:\Users\Aarya-2\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: 'Business'')
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import ydata_profiling as ydp

# Assuming your DataFrame is loaded as 'df'
profile = ydp.ProfileReport(df)
profile.to_file('output.html')  # Save report as HTML
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# c:\Users\Aarya-2\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: 'Business'')
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# get he unique starting points and the unique destination 
print(df['START'].unique())
# Out:
# ['Fort Pierce' 'West Palm Beach' 'Cary' 'Jamaica' 'New York' 'Elmhurst'
#  'Midtown' 'East Harlem' 'Flatiron District' 'Midtown East'
#  'Hudson Square' 'Lower Manhattan' "Hell's Kitchen" 'Downtown' 'Gulfton'
#  'Houston' 'Eagan Park' 'Morrisville' 'Durham' 'Farmington Woods'
#  'Whitebridge' 'Lake Wellingborough' 'Fayetteville Street' 'Raleigh'
#  'Hazelwood' 'Fairmont' 'Meredith Townes' 'Apex' 'Chapel Hill'
#  'Northwoods' 'Edgehill Farms' 'Tanglewood' 'Preston' 'Eastgate'
#  'East Elmhurst' 'Jackson Heights' 'Long Island City' 'Katunayaka'
#  'Unknown Location' 'Colombo' 'Nugegoda' 'Islamabad' 'R?walpindi'
#  'Noorpur Shahan' 'Heritage Pines' 'Westpark Place' 'Waverly Place'
#  'Wayne Ridge' 'Weston' 'East Austin' 'West University' 'South Congress'
#  'The Drag' 'Congress Ave District' 'Red River District' 'Georgian Acres'
#  'North Austin' 'Coxville' 'Convention Center District' 'Austin' 'Katy'
#  'Sharpstown' 'Sugar Land' 'Galveston' 'Port Bolivar' 'Washington Avenue'
# ...

# %%
print(len(df['START'].unique()))
# Out:
# 177

# %%
print(df['STOP'].unique())
# Out:
# ['Fort Pierce' 'West Palm Beach' 'Palm Beach' 'Cary' 'Morrisville'
#  'New York' 'Queens' 'East Harlem' 'NoMad' 'Midtown' 'Midtown East'
#  'Hudson Square' 'Lower Manhattan' "Hell's Kitchen" 'Queens County'
#  'Gulfton' 'Downtown' 'Houston' 'Jamestown Court' 'Durham' 'Whitebridge'
#  'Lake Wellingborough' 'Raleigh' 'Umstead' 'Hazelwood' 'Westpark Place'
#  'Meredith Townes' 'Leesville Hollow' 'Apex' 'Chapel Hill'
#  'Williamsburg Manor' 'Macgregor Downs' 'Edgehill Farms' 'Northwoods'
#  'Tanglewood' 'Preston' 'Walnut Terrace' 'Jackson Heights' 'East Elmhurst'
#  'Midtown West' 'Long Island City' 'Jamaica' 'Unknown Location' 'Colombo'
#  'Nugegoda' 'Katunayaka' 'Islamabad' 'R?walpindi' 'Noorpur Shahan'
#  'Heritage Pines' 'Waverly Place' 'Wayne Ridge' 'Depot Historic District'
#  'Weston' 'West University' 'South Congress' 'Arts District'
#  'Congress Ave District' 'Red River District' 'The Drag'
#  'Convention Center District' 'North Austin' 'Coxville' 'Katy' 'Alief'
# ...

# %%
print(len(df['STOP'].unique()))
# Out:
# 188

# %% [markdown]
# ALSO NUNIQUE() , CAN be used , they give us the unique places in the given data set

# %%
#Example on how to use sets to do intersection , union and difference

l1 = [1,2,3,4,4]
l2 = [3,4,5,6]

set(l2) - set(l1) # difference  ( whats in l2 and not in l1 )
set(l1) - set(l2) # difference ( whats in l1 and not in l2 )
set(l2) | set(l1) # union 
set(l2) & set(l1) # intersection
# Out:
# {3, 4}

# %%
s_start  = set(df['START']) #names of unique start points
s_stop =  set(df['STOP']) #names of unique start points

print(len(s_start))
print(len(s_stop))
# Out:
# 177
# 188

# %%
s_start & s_stop
# Out:
# {'Agnew',
#  'Almond',
#  'Apex',
#  'Arabi',
#  'Arlington',
#  'Arlington Park at Amberly',
#  'Asheville',
#  'Banner Elk',
#  'Bellevue',
#  'Berkeley',
#  'Boone',
#  'Briar Meadow',
#  'Bryson City',
#  'Burtrose',
#  'CBD',
#  'Capitol One',
#  'Cary',
#  'Central',
#  'Chalmette',
#  'Chapel Hill',
#  'Chessington',
#  'College Avenue',
#  'Colombo',
#  'Columbia Heights',
#  'Congress Ave District',
#  'Convention Center District',
#  'Cory',
#  'Covington',
#  'Coxville',
#  'Daytona Beach',
#  'Downtown',
#  'Durham',
#  'Eagle Rock',
#  'East Elmhurst',
#  'East Harlem',
#  'Edgehill Farms',
#  'El Cerrito',
#  'Elk Park',
#  'Emeryville',
#  'Farmington Woods',
#  'Financial District',
#  'Florence',
#  'Fort Pierce',
#  'Fuquay-Varina',
#  'Galveston',
#  'Gampaha',
#  'Gulfton',
#  'Hayesville',
#  'Hazelwood',
#  "Hell's Kitchen",
#  'Heritage Pines',
#  'Holly Springs',
#  'Houston',
#  'Hudson Square',
#  'Huntington Woods',
#  'Ingleside',
#  'Islamabad',
# ...

# %%
df['START'].value_counts().head(10)
# gives us the popular start points in the givn data set
# Out:
# START
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
# Durham               37
# Lahore               36
# Raleigh              28
# Kar?chi              27
# Westpark Place       17
# Name: count, dtype: int64

# %%
df['STOP'].value_counts().head(10)
# Out:
# STOP
# Cary                203
# Unknown Location    149
# Morrisville          84
# Whitebridge          65
# Islamabad            58
# Durham               36
# Lahore               36
# Raleigh              29
# Kar?chi              26
# Apex                 17
# Name: count, dtype: int64

# %% [markdown]
# PLACES WHERE THE START AND THE STOP DESTINATIONS ARE THE SAME

# %%
df[df['START']==df['STOP']]
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Kar?chi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Kar?chi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Kar?chi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %% [markdown]
# FAVOURITE STARTING POINT BASED ON THE TOTAL MILES THAT HAS TO BE COVERED

# %%
df.groupby('START')['MILES'].sum().sort_values(ascending=False).head(10)
# Out:
# START
# Unknown Location    1976.5
# Cary                1791.3
# Morrisville          671.7
# Raleigh              433.0
# Islamabad            401.2
# Durham               384.4
# Jacksonville         375.2
# Latta                310.3
# Asheville            287.7
# Whitebridge          273.4
# Name: MILES, dtype: float64

# %%
k3 = df.groupby('START')['MILES'].sum().sort_values(ascending=False).head(10) 
k3= k3.reset_index() # flattens the dataframe 
k3.columns = ['START' ,'sum_of_miles']
# %matplotlib inline 
import seaborn as sns
sns.barplot(data= k3 , x= 'START' , y ='sum_of_miles')
# Out:
# <Axes: xlabel='START', ylabel='sum_of_miles'>

# %%
#Dropping Unknown Location Value  - Save into anothe dataframe ( dont want to overwrite the original df)
df2 = df[df['START']!= 'Unknown Location']
df2 = df2[df2['STOP']!= 'Unknown Location']

df2.groupby(['START','STOP'])['MILES'].sum().sort_values(ascending=False).head(10)
# Out:
# START         STOP
# Morrisville   Cary            395.7
# Cary          Durham          390.0
#               Morrisville     380.0
# Raleigh       Cary            365.7
# Cary          Raleigh         336.5
# Durham        Cary            334.4
# Latta         Jacksonville    310.3
# Cary          Cary            255.9
# Jacksonville  Kissimmee       201.0
# Asheville     Mebane          195.9
# Name: MILES, dtype: float64

# %% [markdown]
# The most popular start and stop by the travelling distance we use SIZE() operator

# %%
df2.groupby(['START' , 'STOP'])['MILES'].size().sort_values(ascending=False).head()
# Out:
# START        STOP
# Morrisville  Cary           75
# Cary         Morrisville    67
#              Cary           53
#              Durham         36
# Durham       Cary           32
# Name: MILES, dtype: int64

# %% [markdown]
# 2. MANUPLATING DATA AND TIME OBJECTS

# %%
df.head()
# Out:
#        START_DATE        END_DATE  CATEGORY        START             STOP  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
pip install datetime
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from datetime import datetime
df['start_dt'] = df['START_DATE'].apply(lambda x : datetime.strptime(x, '%m/%d/%Y %H:%M'))
df['end_dt'] = df['END_DATE'].apply(lambda x : datetime.strptime(x, '%m/%d/%Y %H:%M'))

# %%
df.head()
df.dtypes
# Out:
# START_DATE            object
# END_DATE              object
# CATEGORY              object
# START                 object
# STOP                  object
# MILES                float64
# PURPOSE               object
# start_dt      datetime64[ns]
# end_dt        datetime64[ns]
# dtype: object

# %%
df['start_day'] = df['start_dt'].dt.day
df['start_hour'] = df['start_dt'].dt.hour
df['start_month'] = df['start_dt'].dt.month
df['week'] = df['start_dt'].dt.dayofweek
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE            start_dt  \
# 0          Fort Pierce    5.1   Meal/Entertain 2016-01-01 21:11:00
# ...
